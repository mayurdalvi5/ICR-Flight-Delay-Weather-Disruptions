# %%
import pandas as pd
import numpy as np

# %%
df_flights = pd.read_csv("/Users/rezanaiman/Desktop/Fall 2024/Stat captson/ICR project/final_merged_2024.csv", low_memory = False)

# %%
df_flights.describe()
# Out:
#            YEAR   QUARTER     MONTH   DAY_OF_MONTH    DAY_OF_WEEK  \
# count  121884.0  121884.0  121884.0  121884.000000  121884.000000
# mean     2024.0       1.0       1.0      16.261618       3.813651
# std         0.0       0.0       0.0       8.803848       2.014112
# min      2024.0       1.0       1.0       1.000000       1.000000
# 25%      2024.0       1.0       1.0       9.000000       2.000000
# 50%      2024.0       1.0       1.0      16.000000       4.000000
# 75%      2024.0       1.0       1.0      24.000000       6.000000
# max      2024.0       1.0       1.0      31.000000       7.000000
#
#        OP_CARRIER_AIRLINE_ID  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# count          121884.000000      121884.000000           5.800000e+04
# mean            20004.282080       12329.953062           1.200599e+06
# std               382.601389        1312.190489           1.316687e+05
# min             19393.000000       10135.000000           1.013506e+06
# ...

# %%
df_flights.shape
# Out:
# (121884, 69)

# %%
df_flights.head(15)
# Out:
#     YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK        FL_DATE  \
# 0   2024        1      1             1            1  1/1/2024 0:00
# 1   2024        1      1             1            1  1/1/2024 0:00
# 2   2024        1      1             1            1  1/1/2024 0:00
# 3   2024        1      1             1            1  1/1/2024 0:00
# 4   2024        1      1             1            1  1/1/2024 0:00
# 5   2024        1      1             1            1  1/1/2024 0:00
# 6   2024        1      1             1            1  1/1/2024 0:00
# 7   2024        1      1             1            1  1/1/2024 0:00
# 8   2024        1      1             1            1  1/1/2024 0:00
# 9   2024        1      1             1            1  1/1/2024 0:00
# 10  2024        1      1             1            1  1/1/2024 0:00
# 11  2024        1      1             1            1  1/1/2024 0:00
# 12  2024        1      1             1            1  1/1/2024 0:00
# ...

# %%
colorado_count = df_flights[df_flights["ORIGIN_AIRPORT_ID"].isin([10325, 11292, 11784])].shape[0]

# %%
print("Number of observation in the dataset of Colorado Airports ", colorado_count)
diff  = 121884 - 28301
diff
# Out:
# Number of observation in the dataset of Colorado Airports  28301
# 93583

# %% [markdown]
#
# - 10325 is the Airport ID for Denver Centenial Airport
# - 11292 is the Airport ID for Denver International Airport
# - 11784 is the Colorado Air and Spcae Port
#
# The combination of these airports makes up the 28301 observations in Colorado. So 93583 of the observations belong to New York.

# %%
df_flights.shape
df_flights_clean = df_flights.dropna(subset=df_flights.columns[27:67],how = 'any')
df_flights_clean
# Out:
# Empty DataFrame
# Columns: [YEAR, QUARTER, MONTH, DAY_OF_MONTH, DAY_OF_WEEK, FL_DATE, OP_UNIQUE_CARRIER, OP_CARRIER_AIRLINE_ID, TAIL_NUM, ORIGIN_AIRPORT_ID, ORIGIN_AIRPORT_SEQ_ID, ORIGIN_CITY_MARKET_ID, ORIGIN, ORIGIN_CITY_NAME, ORIGIN_STATE_ABR, ORIGIN_STATE_NM, DEST_AIRPORT_ID, DEST_AIRPORT_SEQ_ID, DEST_CITY_MARKET_ID, DEST, DEST_CITY_NAME, DEST_STATE_ABR, DEST_STATE_NM, CRS_DEP_TIME, DEP_TIME, DEP_DELAY, DEP_DELAY_NEW, DEP_TIME_BLK, CRS_ARR_TIME, ARR_TIME, ARR_DELAY, ARR_DELAY_NEW, ARR_TIME_BLK, CANCELLED, CANCELLATION_CODE, AIR_TIME, FLIGHTS, DISTANCE, WEATHER_DELAY, departure_datetime, rounded_departure, station, valid, tmpf, dwpf, relh, drct, sknt, p01i, alti, mslp, vsby, gust, skyc1, skyc2, skyc3, skyc4, skyl1, skyl2, skyl3, skyl4, wxcodes, peak_wind_gust, peak_wind_drct, peak_wind_time, feel, metar, snowdepth, rounded_valid]
# Index: []
#
# [0 rows x 69 columns]

# %%
df_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121884 entries, 0 to 121883
# Data columns (total 69 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   YEAR                   121884 non-null  int64
#  1   QUARTER                121884 non-null  int64
#  2   MONTH                  121884 non-null  int64
#  3   DAY_OF_MONTH           121884 non-null  int64
#  4   DAY_OF_WEEK            121884 non-null  int64
#  5   FL_DATE                121884 non-null  object
#  6   OP_UNIQUE_CARRIER      121884 non-null  object
#  7   OP_CARRIER_AIRLINE_ID  121884 non-null  int64
#  8   TAIL_NUM               120394 non-null  object
#  9   ORIGIN_AIRPORT_ID      121884 non-null  int64
#  10  ORIGIN_AIRPORT_SEQ_ID  58000 non-null   float64
#  11  ORIGIN_CITY_MARKET_ID  121884 non-null  int64
#  12  ORIGIN                 121884 non-null  object
#  13  ORIGIN_CITY_NAME       58000 non-null   object
# ...

# %%
count_cancellation = df_flights["CANCELLATION_CODE"].isna().sum()
count_cancellation
# Out:
# 119085

# %% [markdown]
# The cancellation code column has a lot of na values, so we will have to drop it

# %%
df_flights_clean = df_flights.drop('CANCELLATION_CODE', axis = 1)

# %%
df_flights_clean.shape
df_flights_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121884 entries, 0 to 121883
# Data columns (total 68 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   YEAR                   121884 non-null  int64
#  1   QUARTER                121884 non-null  int64
#  2   MONTH                  121884 non-null  int64
#  3   DAY_OF_MONTH           121884 non-null  int64
#  4   DAY_OF_WEEK            121884 non-null  int64
#  5   FL_DATE                121884 non-null  object
#  6   OP_UNIQUE_CARRIER      121884 non-null  object
#  7   OP_CARRIER_AIRLINE_ID  121884 non-null  int64
#  8   TAIL_NUM               120394 non-null  object
#  9   ORIGIN_AIRPORT_ID      121884 non-null  int64
#  10  ORIGIN_AIRPORT_SEQ_ID  58000 non-null   float64
#  11  ORIGIN_CITY_MARKET_ID  121884 non-null  int64
#  12  ORIGIN                 121884 non-null  object
#  13  ORIGIN_CITY_NAME       58000 non-null   object
# ...

# %%
df_flights_without_na = df_flights_clean.dropna()

# %%
df_flights_without_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9449 entries, 15 to 57964
# Data columns (total 68 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   YEAR                   9449 non-null   int64
#  1   QUARTER                9449 non-null   int64
#  2   MONTH                  9449 non-null   int64
#  3   DAY_OF_MONTH           9449 non-null   int64
#  4   DAY_OF_WEEK            9449 non-null   int64
#  5   FL_DATE                9449 non-null   object
#  6   OP_UNIQUE_CARRIER      9449 non-null   object
#  7   OP_CARRIER_AIRLINE_ID  9449 non-null   int64
#  8   TAIL_NUM               9449 non-null   object
#  9   ORIGIN_AIRPORT_ID      9449 non-null   int64
#  10  ORIGIN_AIRPORT_SEQ_ID  9449 non-null   float64
#  11  ORIGIN_CITY_MARKET_ID  9449 non-null   int64
#  12  ORIGIN                 9449 non-null   object
#  13  ORIGIN_CITY_NAME       9449 non-null   object
# ...

# %% [markdown]
# Droping na values results in a significant data loss, do we drop all na values? How should we handle it.
