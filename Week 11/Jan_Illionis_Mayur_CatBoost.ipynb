# %%
import pandas as pd
import numpy as np

from catboost import CatBoostClassifier, Pool
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('E:/Capstone_ICR_Project/Dataset/State_wise_Data_final/Illinois_10_years_data.csv')

# %%
df.head()
# Out:
#    Year  Quarter  Month  Day_of_Month  Day_of_Week Operating_Carrier_Code  \
# 0  2014        2      4           1.0          2.0                     AA
# 1  2014        2      4           1.0          2.0                     AA
# 2  2014        2      4           1.0          2.0                     AA
# 3  2014        2      4           1.0          2.0                     AA
# 4  2014        2      4           1.0          2.0                     AA
#
#   Tail_Number  Origin_Airport_ID Origin_Airport_Code Origin_State_Name  ...  \
# 0      N359AA            13930.0                 ORD          Illinois  ...
# 1      N3ADAA            13930.0                 ORD          Illinois  ...
# 2      N3AKAA            13930.0                 ORD          Illinois  ...
# 3      N3AKAA            13930.0                 ORD          Illinois  ...
# 4      N3ANAA            13930.0                 ORD          Illinois  ...
#
#   Wind_Direction_Degrees Wind_Speed_Knots  Hourly_Precipitation_Inches  \
# 0                  260.0             15.0                          0.0
# 1                  260.0             24.0                          0.0
# 2                  220.0             15.0                          0.0
# 3                  250.0             20.0                          0.0
# 4                  220.0             15.0                          0.0
#
#    Pressure_Altimeter_Inches  Sea_Level_Pressure_Millibar  Visibility_Miles  \
# 0                       30.0                       1014.2              10.0
# 1                       30.0                       1008.9              10.0
# 2                       30.0                       1004.2              10.0
# 3                       30.0                       1011.5              10.0
# 4                       30.0                       1004.2              10.0
#
#   Sky_Cover_Level_1  Sky_Level_1_Altitude_Feet  \
# 0               SCT                    22000.0
# 1               SCT                     2800.0
# 2               SCT                     4300.0
# 3               OVC                     2600.0
# 4               CLR                     4700.0
#
#    Apparent_Temperature_Fahrenheit  Target
# 0                            40.28     0.0
# 1                            20.44     0.0
# 2                            55.04     0.0
# 3                            21.74     0.0
# 4                            55.26     0.0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2969937 entries, 0 to 2969936
# Data columns (total 31 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Year                              int64
#  1   Quarter                           int64
#  2   Month                             int64
#  3   Day_of_Month                      float64
#  4   Day_of_Week                       float64
#  5   Operating_Carrier_Code            object
#  6   Tail_Number                       object
#  7   Origin_Airport_ID                 float64
#  8   Origin_Airport_Code               object
#  9   Origin_State_Name                 object
#  10  Destination_Airport_Code          object
#  11  Destination_State_Name            object
#  12  Scheduled_Departure_Time          float64
#  13  Departure_Delay_Minutes           float64
#  14  Taxi_Out_Time_Minutes             float64
#  15  Flight_Distance_Miles             float64
#  16  Departure_Datetime                object
#  17  Scheduled_Departure_Time_Minutes  float64
#  18  Air_Temperature_Fahrenheit        float64
#  19  Dew_Point_Temperature_Fahrenheit  float64
#  20  Relative_Humidity_Percent         float64
#  21  Wind_Direction_Degrees            float64
#  22  Wind_Speed_Knots                  float64
#  23  Hourly_Precipitation_Inches       float64
#  24  Pressure_Altimeter_Inches         float64
#  25  Sea_Level_Pressure_Millibar       float64
#  26  Visibility_Miles                  float64
#  27  Sky_Cover_Level_1                 object
#  28  Sky_Level_1_Altitude_Feet         float64
#  29  Apparent_Temperature_Fahrenheit   float64
#  30  Target                            float64
# dtypes: float64(20), int64(3), object(8)
# memory usage: 702.4+ MB

# %%
df.isna().sum()
# Out:
# Year                                0
# Quarter                             0
# Month                               0
# Day_of_Month                        0
# Day_of_Week                         0
# Operating_Carrier_Code              0
# Tail_Number                         0
# Origin_Airport_ID                   0
# Origin_Airport_Code                 0
# Origin_State_Name                   0
# Destination_Airport_Code            0
# Destination_State_Name              0
# Scheduled_Departure_Time            0
# Departure_Delay_Minutes             0
# Taxi_Out_Time_Minutes               0
# Flight_Distance_Miles               0
# Departure_Datetime                  0
# Scheduled_Departure_Time_Minutes    0
# Air_Temperature_Fahrenheit          0
# Dew_Point_Temperature_Fahrenheit    0
# Relative_Humidity_Percent           0
# Wind_Direction_Degrees              0
# Wind_Speed_Knots                    0
# Hourly_Precipitation_Inches         0
# Pressure_Altimeter_Inches           0
# Sea_Level_Pressure_Millibar         0
# Visibility_Miles                    0
# Sky_Cover_Level_1                   0
# Sky_Level_1_Altitude_Feet           0
# Apparent_Temperature_Fahrenheit     0
# Target                              0
# dtype: int64

# %%
df.dropna(inplace= True)

# %%
# Convert integer features to int32
int_columns = [
    'Year', 
    'Quarter', 
    'Month', 
    'Day_of_Month', 
    'Day_of_Week', 
    'Scheduled_Departure_Time', 
    'Scheduled_Departure_Time_Minutes',
    'Target'
]

for col in int_columns:
    df[col] = df[col].astype(np.int32)

# Convert continuous numeric features to float32
float_columns = [
    'Departure_Delay_Minutes',
    'Taxi_Out_Time_Minutes',
    'Flight_Distance_Miles',
    'Air_Temperature_Fahrenheit',
    'Dew_Point_Temperature_Fahrenheit',
    'Relative_Humidity_Percent',
    'Wind_Direction_Degrees',
    'Wind_Speed_Knots',
    'Hourly_Precipitation_Inches',
    'Pressure_Altimeter_Inches',
    'Sea_Level_Pressure_Millibar',
    'Visibility_Miles',
    'Sky_Level_1_Altitude_Feet',
    'Apparent_Temperature_Fahrenheit',
    
]

for col in float_columns:
    df[col] = df[col].astype(np.float32)

# Convert categorical features to 'category' dtype
categorical_columns = [
    'Operating_Carrier_Code',
    'Tail_Number',
    'Origin_Airport_ID',
    'Origin_Airport_Code',
    'Origin_State_Name',
    'Destination_Airport_Code',
    'Destination_State_Name',
    'Sky_Cover_Level_1'
]

for col in categorical_columns:
    df[col] = df[col].astype('category')

# %%
df = df.drop([ 'Origin_State_Name','Departure_Datetime','Departure_Delay_Minutes'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2969937 entries, 0 to 2969936
# Data columns (total 28 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Year                              int32
#  1   Quarter                           int32
#  2   Month                             int32
#  3   Day_of_Month                      int32
#  4   Day_of_Week                       int32
#  5   Operating_Carrier_Code            category
#  6   Tail_Number                       category
#  7   Origin_Airport_ID                 category
#  8   Origin_Airport_Code               category
#  9   Destination_Airport_Code          category
#  10  Destination_State_Name            category
#  11  Scheduled_Departure_Time          int32
#  12  Taxi_Out_Time_Minutes             float32
#  13  Flight_Distance_Miles             float32
#  14  Scheduled_Departure_Time_Minutes  int32
#  15  Air_Temperature_Fahrenheit        float32
#  16  Dew_Point_Temperature_Fahrenheit  float32
#  17  Relative_Humidity_Percent         float32
#  18  Wind_Direction_Degrees            float32
#  19  Wind_Speed_Knots                  float32
#  20  Hourly_Precipitation_Inches       float32
#  21  Pressure_Altimeter_Inches         float32
#  22  Sea_Level_Pressure_Millibar       float32
#  23  Visibility_Miles                  float32
#  24  Sky_Cover_Level_1                 category
#  25  Sky_Level_1_Altitude_Feet         float32
#  26  Apparent_Temperature_Fahrenheit   float32
#  27  Target                            int32
# dtypes: category(7), float32(13), int32(8)
# memory usage: 263.7 MB

# %%
df['Year'].value_counts()
# Out:
# Year
# 2019    426951
# 2020    420073
# 2015    395345
# 2014    362592
# 2017    301209
# 2023    300540
# 2016    292813
# 2021    254563
# 2018    166021
# 2024     25193
# 2022     24637
# Name: count, dtype: int64

# %%
df1= df[df['Month'] == 1]

# %%
train_df['Year'].value_counts()
# Out:
# Year
# 2018    32116
# 2019    30290
# 2015    30099
# 2017    25477
# 2016    25412
# 2014    15129
# Name: count, dtype: int64

# %%
df1['Year'] = df1['Year'].astype(int)

train_years = [2014, 2015, 2016, 2017, 2018, 2019]
val_years = [2020, 2021, 2022]
test_years = [2023, 2024]

# %%
# Create the training set
train_df = df1[df1['Year'].isin(train_years)].reset_index(drop=True)

# Create the validation set
val_df = df1[df1['Year'].isin(val_years)].reset_index(drop=True)

# Create the test set
test_df = df1[df1['Year'].isin(test_years)].reset_index(drop=True)

# Separate features and target
X_train = train_df.drop('Target', axis=1)
y_train = train_df['Target']

X_val = val_df.drop('Target', axis=1)
y_val = val_df['Target']

X_test = test_df.drop('Target', axis=1)
y_test = test_df['Target']
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8308\3063133705.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Year'] = df1['Year'].astype(int)

# %%
cat_features = X_train.select_dtypes(include=['category']).columns.tolist()

for cat_col in cat_features:
    X_train[cat_col] = X_train[cat_col].astype(str)
    X_val[cat_col] = X_val[cat_col].astype(str)
    X_test[cat_col] = X_test[cat_col].astype(str)

# %%
cat_features
# Out:
# ['Operating_Carrier_Code',
#  'Tail_Number',
#  'Origin_Airport_ID',
#  'Origin_Airport_Code',
#  'Destination_Airport_Code',
#  'Destination_State_Name',
#  'Sky_Cover_Level_1']

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(zip(np.unique(y_train), class_weights))

print(f"Class Weights: {class_weights}")
# Out:
# Class Weights: {0: 0.6878547253319448, 1: 1.8308156052941584}

# %%
train_pool = Pool(data=X_train, label=y_train, cat_features=cat_features)
val_pool = Pool(data=X_val, label=y_val, cat_features=cat_features)

model = CatBoostClassifier(
    iterations=1000,
    learning_rate=0.01,
    eval_metric='F1',
    random_seed=42,
    use_best_model=True,
    class_weights=[class_weights[0], class_weights[1]],
    early_stopping_rounds=100,
    l2_leaf_reg=3,
    border_count=254,
    depth=6
)

model.fit(
    train_pool,
    eval_set=val_pool,
    verbose=100
)
# Out:
# 0:	learn: 0.6210115	test: 0.4449313	best: 0.4449313 (0)	total: 354ms	remaining: 5m 53s
# 100:	learn: 0.6631658	test: 0.4559437	best: 0.4736184 (2)	total: 31.7s	remaining: 4m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.4736184048
# bestIteration = 2
#
# Shrink model to first 3 iterations.

# %%
test_pool = Pool(data=X_test, label=y_test, cat_features=cat_features)

y_pred = model.predict(test_pool)
y_pred_proba = model.predict_proba(test_pool)[:, 1]

# Evaluate the model
test_accuracy = accuracy_score(y_test, y_pred)
print(f'Test Accuracy: {test_accuracy}\n')

print('Classification Report:')
print(classification_report(y_test, y_pred))

print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))
# Out:
# Test Accuracy: 0.6501409121581392
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.70      0.74     18140
#            1       0.40      0.51      0.45      7053
#
#     accuracy                           0.65     25193
#    macro avg       0.59      0.61      0.60     25193
# weighted avg       0.68      0.65      0.66     25193
#
# Confusion Matrix:
# [[12768  5372]
#  [ 3442  3611]]

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score

# Prepare data for cross-validation
X_cv = pd.concat([X_train, X_val], axis=0)
y_cv = pd.concat([y_train, y_val], axis=0)

for cat_col in cat_features:
    X_cv[cat_col] = X_cv[cat_col].astype(str)

# Initialize Stratified K-Fold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

model_cv = CatBoostClassifier(
    iterations=1000,
    learning_rate=0.01,
    eval_metric='F1',
    random_seed=42,
    use_best_model=False,
    class_weights=[class_weights[0], class_weights[1]],
    l2_leaf_reg=3,
    border_count=254,
    depth=6
)

cv_scores = []

for train_index, test_index in skf.split(X_cv, y_cv):
    X_fold_train, X_fold_val = X_cv.iloc[train_index], X_cv.iloc[test_index]
    y_fold_train, y_fold_val = y_cv.iloc[train_index], y_cv.iloc[test_index]
    
    train_pool_cv = Pool(data=X_fold_train, label=y_fold_train, cat_features=cat_features)
    val_pool_cv = Pool(data=X_fold_val, label=y_fold_val, cat_features=cat_features)
    
    model_cv.fit(
        train_pool_cv,
        eval_set=val_pool_cv,
        verbose=100,
        early_stopping_rounds=100
    )
    
    y_fold_pred = model_cv.predict(val_pool_cv)
    fold_f1 = classification_report(y_fold_val, y_fold_pred, output_dict=True)['1']['f1-score']
    cv_scores.append(fold_f1)
    print(f'Fold F1-Score: {fold_f1}\n')

print(f'Mean F1-Score from Cross-Validation: {np.mean(cv_scores)}')
# Out:
# 0:	learn: 0.5740489	test: 0.5798735	best: 0.5798735 (0)	total: 299ms	remaining: 4m 58s
# 100:	learn: 0.6122586	test: 0.6171229	best: 0.6171229 (100)	total: 31.5s	remaining: 4m 40s
# 200:	learn: 0.6244373	test: 0.6301543	best: 0.6302337 (195)	total: 1m 6s	remaining: 4m 25s
# 300:	learn: 0.6320269	test: 0.6365470	best: 0.6369849 (278)	total: 1m 40s	remaining: 3m 53s
# 400:	learn: 0.6390320	test: 0.6440725	best: 0.6440725 (400)	total: 2m 14s	remaining: 3m 20s
# 500:	learn: 0.6435561	test: 0.6476493	best: 0.6481933 (495)	total: 2m 49s	remaining: 2m 48s
# 600:	learn: 0.6475939	test: 0.6504881	best: 0.6509319 (573)	total: 3m 24s	remaining: 2m 16s
# 700:	learn: 0.6505656	test: 0.6536980	best: 0.6536980 (700)	total: 3m 58s	remaining: 1m 41s
# 800:	learn: 0.6537453	test: 0.6568823	best: 0.6570540 (793)	total: 4m 32s	remaining: 1m 7s
# 900:	learn: 0.6566541	test: 0.6587277	best: 0.6588743 (890)	total: 5m 6s	remaining: 33.7s
# 999:	learn: 0.6592877	test: 0.6591633	best: 0.6601312 (946)	total: 5m 40s	remaining: 0us
#
# bestTest = 0.6601312261
# bestIteration = 946
#
# Fold F1-Score: 0.53939021894823
#
# 0:	learn: 0.5898555	test: 0.5906756	best: 0.5906756 (0)	total: 300ms	remaining: 4m 59s
# 100:	learn: 0.6135268	test: 0.6161061	best: 0.6162017 (97)	total: 33s	remaining: 4m 53s
# 200:	learn: 0.6265182	test: 0.6287262	best: 0.6287817 (199)	total: 1m 7s	remaining: 4m 26s
# 300:	learn: 0.6339615	test: 0.6348267	best: 0.6348267 (300)	total: 1m 40s	remaining: 3m 53s
# 400:	learn: 0.6409242	test: 0.6392962	best: 0.6392962 (400)	total: 2m 15s	remaining: 3m 22s
# 500:	learn: 0.6458149	test: 0.6423376	best: 0.6423376 (500)	total: 2m 47s	remaining: 2m 47s
# 600:	learn: 0.6497320	test: 0.6454370	best: 0.6455301 (598)	total: 3m 19s	remaining: 2m 12s
# 700:	learn: 0.6522799	test: 0.6489051	best: 0.6491097 (697)	total: 3m 51s	remaining: 1m 38s
# 800:	learn: 0.6552973	test: 0.6518685	best: 0.6518685 (800)	total: 4m 23s	remaining: 1m 5s
# 900:	learn: 0.6583533	test: 0.6535592	best: 0.6535592 (900)	total: 4m 55s	remaining: 32.4s
# 999:	learn: 0.6606393	test: 0.6560293	best: 0.6561645 (997)	total: 5m 26s	remaining: 0us
#
# bestTest = 0.6561645116
# bestIteration = 997
#
# Fold F1-Score: 0.5379475334103283
#
# 0:	learn: 0.5853301	test: 0.5781772	best: 0.5781772 (0)	total: 329ms	remaining: 5m 28s
# 100:	learn: 0.6140011	test: 0.6086617	best: 0.6086617 (100)	total: 31.5s	remaining: 4m 40s
# 200:	learn: 0.6274308	test: 0.6187630	best: 0.6191276 (194)	total: 1m 4s	remaining: 4m 18s
# 300:	learn: 0.6343865	test: 0.6252029	best: 0.6253097 (299)	total: 1m 38s	remaining: 3m 49s
# 400:	learn: 0.6407761	test: 0.6309439	best: 0.6312918 (399)	total: 2m 32s	remaining: 3m 47s
# 500:	learn: 0.6457373	test: 0.6359079	best: 0.6359323 (495)	total: 3m 14s	remaining: 3m 13s
# 600:	learn: 0.6492282	test: 0.6400601	best: 0.6400601 (600)	total: 3m 46s	remaining: 2m 30s
# 700:	learn: 0.6524524	test: 0.6438861	best: 0.6439231 (698)	total: 4m 19s	remaining: 1m 50s
# 800:	learn: 0.6549106	test: 0.6453887	best: 0.6458514 (788)	total: 4m 50s	remaining: 1m 12s
# 900:	learn: 0.6569295	test: 0.6482398	best: 0.6484580 (890)	total: 5m 21s	remaining: 35.4s
# 999:	learn: 0.6596734	test: 0.6505872	best: 0.6506184 (998)	total: 5m 52s	remaining: 0us
#
# bestTest = 0.6506183904
# bestIteration = 998
#
# Fold F1-Score: 0.5344992712887778
#
# 0:	learn: 0.5985792	test: 0.5919697	best: 0.5919697 (0)	total: 334ms	remaining: 5m 33s
# 100:	learn: 0.6155206	test: 0.6079359	best: 0.6079359 (100)	total: 32.3s	remaining: 4m 47s
# 200:	learn: 0.6295872	test: 0.6195213	best: 0.6195452 (199)	total: 1m 4s	remaining: 4m 17s
# 300:	learn: 0.6359860	test: 0.6255401	best: 0.6255401 (300)	total: 1m 35s	remaining: 3m 42s
# 400:	learn: 0.6416779	test: 0.6309499	best: 0.6310143 (390)	total: 2m 9s	remaining: 3m 13s
# 500:	learn: 0.6469839	test: 0.6365271	best: 0.6365271 (500)	total: 2m 40s	remaining: 2m 40s
# 600:	learn: 0.6510058	test: 0.6397795	best: 0.6399053 (599)	total: 3m 13s	remaining: 2m 8s
# 700:	learn: 0.6543507	test: 0.6429692	best: 0.6433053 (659)	total: 3m 45s	remaining: 1m 36s
# 800:	learn: 0.6577061	test: 0.6450621	best: 0.6454536 (794)	total: 4m 18s	remaining: 1m 4s
# 900:	learn: 0.6604067	test: 0.6479739	best: 0.6485129 (895)	total: 4m 50s	remaining: 31.9s
# 999:	learn: 0.6626286	test: 0.6506345	best: 0.6508386 (993)	total: 5m 21s	remaining: 0us
#
# bestTest = 0.6508386326
# bestIteration = 993
#
# Fold F1-Score: 0.5325243519894337
#
# 0:	learn: 0.5653408	test: 0.5661825	best: 0.5661825 (0)	total: 303ms	remaining: 5m 3s
# 100:	learn: 0.6146108	test: 0.6161686	best: 0.6163592 (99)	total: 31.4s	remaining: 4m 39s
# 200:	learn: 0.6266119	test: 0.6274372	best: 0.6274372 (200)	total: 1m 5s	remaining: 4m 20s
# 300:	learn: 0.6334620	test: 0.6367021	best: 0.6369216 (298)	total: 1m 36s	remaining: 3m 44s
# 400:	learn: 0.6398747	test: 0.6424769	best: 0.6424769 (400)	total: 2m 8s	remaining: 3m 11s
# 500:	learn: 0.6445355	test: 0.6476482	best: 0.6478020 (490)	total: 2m 42s	remaining: 2m 41s
# 600:	learn: 0.6488180	test: 0.6511832	best: 0.6512263 (592)	total: 3m 14s	remaining: 2m 8s
# 700:	learn: 0.6524500	test: 0.6524683	best: 0.6527632 (682)	total: 3m 45s	remaining: 1m 36s
# 800:	learn: 0.6550240	test: 0.6560837	best: 0.6561633 (798)	total: 4m 17s	remaining: 1m 3s
# 900:	learn: 0.6581642	test: 0.6580304	best: 0.6580851 (894)	total: 4m 51s	remaining: 32s
# 999:	learn: 0.6605912	test: 0.6594540	best: 0.6595333 (998)	total: 5m 22s	remaining: 0us
#
# bestTest = 0.6595332612
# bestIteration = 998
#
# Fold F1-Score: 0.5387405746892194
#
# Mean F1-Score from Cross-Validation: 0.5366203900651978
